# %%
from crewai import Agent, Task, Crew, Process, LLM

# LLM
llm = LLM(
    model="groq/llama-3.1-8b-instant",
    api_key=GROQ_API_KEY
)

# Agent 1
skill_analyzer = Agent(
    role="Skill Analyzer",
    goal="Analyze student skills and strengths",
    backstory="You are an expert in evaluating student abilities.",
    llm=llm,
    verbose=True
)

# Agent 2
career_advisor = Agent(
    role="Career Advisor",
    goal="Suggest suitable career paths",
    backstory="You help students choose careers.",
    llm=llm,
    verbose=True
)

# Agent 3
learning_mentor = Agent(
    role="Learning Mentor",
    goal="Create a learning roadmap",
    backstory="You design study plans and learning paths.",
    llm=llm,
    verbose=True
)

# Task 1
analysis_task = Task(
    description="""
    Student Details:

    Skills:
    - Python
    - SQL
    - Communication

    Interests:
    - Artificial Intelligence
    - Data Science

    Analyze strengths and weaknesses.
    """,
    expected_output="Detailed skill analysis.",
    agent=skill_analyzer
)

# Task 2
career_task = Task(
    description="""
    Based on the student's skills and interests,
    recommend suitable career options.
    """,
    expected_output="List of career recommendations.",
    agent=career_advisor
)

# Task 3
roadmap_task = Task(
    description="""
    Create a 6-month roadmap for the student
    to become job-ready.
    """,
    expected_output="Detailed learning roadmap.",
    agent=learning_mentor
)

crew = Crew(
    agents=[
        skill_analyzer,
        career_advisor,
        learning_mentor
    ],
    tasks=[
        analysis_task,
        career_task,
        roadmap_task
    ],
    process=Process.sequential,
    verbose=True
)

result = crew.kickoff()

print("\nFINAL RESULT:\n")
print(result)
# Out:
# WARNING:opentelemetry.trace:Overriding of current TracerProvider is not allowed
# # Agent: Skill Analyzer
# ## Task:
#     Student Details:
#
#     Skills:
#     - Python
#     - SQL
#     - Communication
#
#     Interests:
#     - Artificial Intelligence
#     - Data Science
#
#     Analyze strengths and weaknesses.
#
#
#
# # Agent: Skill Analyzer
# ## Final Answer:
# **Detailed Skill Analysis**
#
# **Technical Skills:**
#
# 1. **Python:**
# 	* Strengths:
# 		+ The student is already familiar with Python, which indicates they have a solid foundation in programming.
# 		+ They may have experience with popular Python libraries such as NumPy, pandas, and Matplotlib, which can be beneficial for their interests in Artificial Intelligence and Data Science.
# 	* Weaknesses:
# 		+ It is unknown if they have experience with advanced Python concepts such as decorators, generators, or asynchronous programming.
# 		+ They may have gaps in their knowledge of Python's standard library or best practices for coding.
# 2. **SQL:**
# 	* Strengths:
# 		+ Having SQL skills indicates the student has experience with relational databases and can extract and manipulate data from them.
# 		+ They may have knowledge of SQL's syntax, including SELECT, INSERT, UPDATE, and DELETE statements, which can be useful for Data Science tasks.
# 	* Weaknesses:
# 		+ It is unclear if they have experience with NoSQL databases or advanced SQL concepts such as window functions or Common Table Expressions.
# 		+ They may have limited knowledge of database design or data modeling.
# 3. **Communication:**
# 	* Strengths:
# 		+ Good communication skills are essential for presenting findings, interpreting results, or collaborating with others.
# 		+ They may be able to effectively articulate complex ideas to non-technical stakeholders or write clear and concise reports.
# 	* Weaknesses:
# 		+ It is unknown if they have experience with public speaking, presenting in front of an audience, or handling questions from experts.
# 		+ They may struggle with active listening or responding to feedback from others.
#
# **Interests:**
#
# 1. **Artificial Intelligence:**
# 	* Strengths:
# 		+ Their interest in Artificial Intelligence suggests they are aware of current trends and applications in the field.
# 		+ They may have knowledge of popular AI libraries such as TensorFlow, PyTorch, or Keras, which can be beneficial for their interests.
# 	* Weaknesses:
# 		+ It is unclear if they have a deep understanding of AI concepts such as machine learning, natural language processing, or computer vision.
# 		+ They may have limited experience with AI-related tools, software, or techniques.
# 2. **Data Science:**
# 	* Strengths:
# 		+ Their interest in Data Science implies they are familiar with data-related tools and techniques, such as data preprocessing, visualization, or statistical analysis.
# 		+ They may have knowledge of popular Data Science libraries such as pandas, NumPy, or Matplotlib.
# 	* Weaknesses:
# 		+ It is unknown if they have experience with advanced Data Science concepts such as regression, clustering, or decision trees.
# 		+ They may have limited knowledge of data visualization tools or techniques such as interactive dashboards or storytelling.
#
# **Overall Analysis:**
#
# The student has a good foundation in Python and SQL, which can be beneficial for their interests in Artificial Intelligence and Data Science. However, there are gaps in their knowledge of advanced programming concepts, SQL, or Data Science techniques. Additionally, their communication skills may benefit from more practice, particularly in public speaking and responding to feedback.
#
# **Recommendations:**
#
# Based on the analysis, the student should prioritize the following areas:
#
# 1. **Expand their programming knowledge:** Focus on advanced Python concepts, such as decorators, generators, or asynchronous programming.
# 2. **Improve their SQL skills:** Study NoSQL databases, advanced SQL concepts, and database design or data modeling.
# 3. **Develop their Data Science skills:** Learn advanced Data Science concepts, such as regression, clustering, or decision trees, and familiarize themselves with popular Data Science libraries and tools.
# 4. **Enhance their communication skills:** Practice public speaking, presenting in front of an audience, and responding to feedback from others.
# 5. **Stay up-to-date with industry trends:** Continuously expand their knowledge of current trends and applications in Artificial Intelligence and Data Science.
#
#
# # Agent: Career Advisor
# ## Task:
#     Based on the student's skills and interests,
#     recommend suitable career options.
#
#
#
# # Agent: Career Advisor
# ## Final Answer:
# Based on the student's skills and interests, I recommend the following career options:
#
# 1. **Data Scientist:** As the student has a good foundation in Python and SQL, they are well-suited for a career in Data Science. They can apply their skills to extract insights from large datasets, develop predictive models, and communicate their findings to stakeholders.
# 2. **Machine Learning Engineer:** Given their interest in Artificial Intelligence, the student can excel as a Machine Learning Engineer. They can design and develop intelligent systems that can learn and adapt to new data, and deploy them in various applications.
# 3. **Business Analyst (Data-Driven):** This role combines business acumen with data analysis skills, making it a suitable fit for the student. They can work with stakeholders to understand business needs, collect and analyze data, and develop insights to inform business decisions.
# 4. **Data Analyst (Business Intelligence):** The student can leverage their SQL skills to work with large datasets and develop reports, dashboards, and visualizations that help organizations make data-driven decisions.
# 5. **Research Assistant (AI/ML):** As the student has an interest in Artificial Intelligence, they can consider a research assistant role in academia or industry. They can support researchers in designing and implementing AI/ML experiments, collecting and analyzing data, and developing publications.
# 6. **Software Developer (Python):** With their strong background in Python, the student can work as a software developer in a variety of industries, such as web development, mobile app development, or game development.
# 7. **Database Administrator:** Their SQL skills make them a strong candidate for a database administration role, where they can design, implement, and maintain databases for organizations.
# 8. **Quantitative Analyst:** In this role, the student can apply their data analysis and problem-solving skills to work in finance, healthcare, or other industries, analyzing complex data to inform business decisions.
# 9. **Academic Researcher (CS):** The student can consider pursuing a research career in computer science, focusing on areas such as machine learning, data science, or human-computer interaction.
# 10. **Consultant (Data-Driven):** As a consultant, the student can work with clients to analyze their data, identify opportunities for improvement, and develop strategic recommendations to drive business growth.
#
#
# # Agent: Learning Mentor
# ## Task:
#     Create a 6-month roadmap for the student
#     to become job-ready.
#
#
#
# # Agent: Learning Mentor
# ## Final Answer:
# **6-Month Learning Roadmap to Job-Readiness**
#
# **Month 1: Building Foundations and Skills Assessment (Weeks 1-4)**
#
# 1. **Python Programming Fundamentals**:
# 	* Review and refine Python basics (data types, control structures, functions, and object-oriented programming).
# 	* Practice solving problems on platforms like LeetCode, HackerRank, or CodeWars.
# 	* Complete projects to demonstrate understanding, such as building a calculator, a game, or a chatbot.
# 2. **Data Analysis with SQL**:
# 	* Review and solidify SQL skills for data querying, manipulation, and analysis.
# 	* Use data science libraries like Pandas, NumPy, and Matplotlib to work with large datasets.
# 	* Practice querying and analyzing real-world datasets.
# 3. **Machine Learning Fundamentals**:
# 	* Introduce basic machine learning concepts, such as supervised and unsupervised learning, regression, classification, clustering, and neural networks.
# 	* Use libraries like Scikit-learn and TensorFlow for hands-on experience.
# 4. **Soft Skills and Time Management**:
# 	* Develop essential communication, teamwork, and problem-solving skills.
# 	* Establish a routine for regular study sessions, project completion, and feedback.
#
# **Assessment**:
#
# * Complete a project demonstrating Python programming skills.
# * Participate in a team-based data analysis project using SQL and data science libraries.
# * Show evidence of soft skills growth and regular study habits.
#
# **Month 2: Data Science and Machine Learning (Weeks 5-8)**
#
# 1. **Data Science and Visualization**:
# 	* Learn and practice data visualization techniques using popular libraries like Matplotlib, Seaborn, and Plotly.
# 	* Develop skills for data wrangling, cleaning, and feature engineering.
# 	* Use real-world datasets to practice visualization and analysis.
# 2. **Machine Learning with Deep Learning**:
# 	* Dive deeper into machine learning, focusing on neural networks, deep learning, and transfer learning.
# 	* Apply machine learning models to real-world problems using Scikit-learn and TensorFlow.
# 	* Practice using popular frameworks for deep learning.
# 3. **Business Acumen and Data-Driven Decision Making**:
# 	* Develop an understanding of business needs, market trends, and data-driven decision making.
# 	* Practice analyzing case studies, financial statements, and marketing reports.
# 4. **Professional Development**:
# 	* Attend webinars, workshops, or conferences related to data science, machine learning, and industry trends.
# 	* Engage in online communities, forums, or professional networks to stay updated.
#
# **Assessment**:
#
# * Complete a data science project using visualization and machine learning techniques.
# * Develop and present a machine learning model using deep learning concepts.
# * Show evidence of growth in business acumen and professional network.
#
# **Month 3: Specialization and Project Development (Weeks 9-12)**
#
# 1. **Choose a Specialization**:
# 	* Select a specialization from the list: data scientist, machine learning engineer, business analyst, data analyst, or research assistant.
# 	* Create a portfolio showcasing relevant projects and skills.
# 	* Develop a professional profile on platforms like LinkedIn or GitHub.
# 2. **Project Development**:
# 	* Identify a project that aligns with the chosen specialization.
# 	* Break down the project into manageable tasks and create a project plan.
# 	* Regularly document progress, and demonstrate adaptability to changes or new learnings.
# 3. **Industry Knowledge and Networking**:
# 	* Read industry reports, articles, or blogs to stay updated on trends and technologies.
# 	* Attend meetups, conferences, or online events related to the chosen specialization.
# 	* Build connections with professionals in the industry.
# 4. **Personal Branding**:
# 	* Develop a personal website, blog, or portfolio to showcase skills and projects.
# 	* Create a consistent and professional online presence.
#
# **Assessment**:
#
# * Showcase a project portfolio that aligns with chosen specialization.
# * Participate in industry-specific networking events.
# * Demonstrate growth in personal branding and online presence.
#
# **Month 4-6: Refining Skills, Preparing for Interviews, and Job Applications**
#
# 1. **Skill Refining**:
# 	* Identify areas for improvement based on skill assessments and feedback.
# 	* Develop a plan to refine skills, including online courses, tutorials, or workshops.
# 2. **Interview Preparation**:
# 	* Practice common interview questions and scenarios.
# 	* Develop a strategy for answering behavioral questions.
# 	* Engage in mock interviews with peers or mentors.
# 3. **Job Applications and Networking**:
# 	* Update the resume and cover letter to highlight relevant skills and experiences.
# 	* Apply to job openings or internships aligning with the chosen specialization.
# 	* Network with professionals in the industry for referrals or advice.
# 4. **Final Project or Capstone**:
# 	* Complete a final project that integrates skills learned throughout the program.
# 	* Showcase the project on platforms like GitHub, Kaggle, or a personal website.
#
# **Assessment**:
#
# * Demonstrate refined skills and growth through skill assessments.
# * Showcase preparedness for interviews through mock interviews and preparation strategies.
# * Document job applications and networking efforts.
#
# **Final Assessment: Job Readiness**
#
# * Participate in a final interview simulation with a panel of industry professionals.
# * Demonstrate confidence and preparedness for a data science or machine learning-related role.
# * Showcase the final project or capstone work.
#
#
#
# FINAL RESULT:
#
# **6-Month Learning Roadmap to Job-Readiness**
#
# **Month 1: Building Foundations and Skills Assessment (Weeks 1-4)**
#
# 1. **Python Programming Fundamentals**:
# 	* Review and refine Python basics (data types, control structures, functions, and object-oriented programming).
# 	* Practice solving problems on platforms like LeetCode, HackerRank, or CodeWars.
# 	* Complete projects to demonstrate understanding, such as building a calculator, a game, or a chatbot.
# 2. **Data Analysis with SQL**:
# 	* Review and solidify SQL skills for data querying, manipulation, and analysis.
# 	* Use data science libraries like Pandas, NumPy, and Matplotlib to work with large datasets.
# 	* Practice querying and analyzing real-world datasets.
# 3. **Machine Learning Fundamentals**:
# 	* Introduce basic machine learning concepts, such as supervised and unsupervised learning, regression, classification, clustering, and neural networks.
# 	* Use libraries like Scikit-learn and TensorFlow for hands-on experience.
# 4. **Soft Skills and Time Management**:
# 	* Develop essential communication, teamwork, and problem-solving skills.
# 	* Establish a routine for regular study sessions, project completion, and feedback.
#
# **Assessment**:
#
# * Complete a project demonstrating Python programming skills.
# * Participate in a team-based data analysis project using SQL and data science libraries.
# * Show evidence of soft skills growth and regular study habits.
#
# **Month 2: Data Science and Machine Learning (Weeks 5-8)**
#
# 1. **Data Science and Visualization**:
# 	* Learn and practice data visualization techniques using popular libraries like Matplotlib, Seaborn, and Plotly.
# 	* Develop skills for data wrangling, cleaning, and feature engineering.
# 	* Use real-world datasets to practice visualization and analysis.
# 2. **Machine Learning with Deep Learning**:
# 	* Dive deeper into machine learning, focusing on neural networks, deep learning, and transfer learning.
# 	* Apply machine learning models to real-world problems using Scikit-learn and TensorFlow.
# 	* Practice using popular frameworks for deep learning.
# 3. **Business Acumen and Data-Driven Decision Making**:
# 	* Develop an understanding of business needs, market trends, and data-driven decision making.
# 	* Practice analyzing case studies, financial statements, and marketing reports.
# 4. **Professional Development**:
# 	* Attend webinars, workshops, or conferences related to data science, machine learning, and industry trends.
# 	* Engage in online communities, forums, or professional networks to stay updated.
#
# **Assessment**:
#
# * Complete a data science project using visualization and machine learning techniques.
# * Develop and present a machine learning model using deep learning concepts.
# * Show evidence of growth in business acumen and professional network.
#
# **Month 3: Specialization and Project Development (Weeks 9-12)**
#
# 1. **Choose a Specialization**:
# 	* Select a specialization from the list: data scientist, machine learning engineer, business analyst, data analyst, or research assistant.
# 	* Create a portfolio showcasing relevant projects and skills.
# 	* Develop a professional profile on platforms like LinkedIn or GitHub.
# 2. **Project Development**:
# 	* Identify a project that aligns with the chosen specialization.
# 	* Break down the project into manageable tasks and create a project plan.
# 	* Regularly document progress, and demonstrate adaptability to changes or new learnings.
# 3. **Industry Knowledge and Networking**:
# 	* Read industry reports, articles, or blogs to stay updated on trends and technologies.
# 	* Attend meetups, conferences, or online events related to the chosen specialization.
# 	* Build connections with professionals in the industry.
# 4. **Personal Branding**:
# 	* Develop a personal website, blog, or portfolio to showcase skills and projects.
# 	* Create a consistent and professional online presence.
#
# **Assessment**:
#
# * Showcase a project portfolio that aligns with chosen specialization.
# * Participate in industry-specific networking events.
# * Demonstrate growth in personal branding and online presence.
#
# **Month 4-6: Refining Skills, Preparing for Interviews, and Job Applications**
#
# 1. **Skill Refining**:
# 	* Identify areas for improvement based on skill assessments and feedback.
# 	* Develop a plan to refine skills, including online courses, tutorials, or workshops.
# 2. **Interview Preparation**:
# 	* Practice common interview questions and scenarios.
# 	* Develop a strategy for answering behavioral questions.
# 	* Engage in mock interviews with peers or mentors.
# 3. **Job Applications and Networking**:
# 	* Update the resume and cover letter to highlight relevant skills and experiences.
# 	* Apply to job openings or internships aligning with the chosen specialization.
# 	* Network with professionals in the industry for referrals or advice.
# 4. **Final Project or Capstone**:
# 	* Complete a final project that integrates skills learned throughout the program.
# 	* Showcase the project on platforms like GitHub, Kaggle, or a personal website.
#
# **Assessment**:
#
# * Demonstrate refined skills and growth through skill assessments.
# * Showcase preparedness for interviews through mock interviews and preparation strategies.
# * Document job applications and networking efforts.
#
# **Final Assessment: Job Readiness**
#
# * Participate in a final interview simulation with a panel of industry professionals.
# * Demonstrate confidence and preparedness for a data science or machine learning-related role.
# * Showcase the final project or capstone work.
